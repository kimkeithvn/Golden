# %% [markdown]
# # 本文内容

# %% [markdown]
# 本文为MDCSpell: A Multi-task Detector-Corrector Framework for Chinese Spelling Correction论文的Pytorch实现。
#
# [论文地址](https://aclanthology.org/2022.findings-acl.98/): https://aclanthology.org/2022.findings-acl.98/
#
# 论文年份：2022
#
# [论文笔记](https://blog.csdn.net/zhaohongfei_358/article/details/126973451)：https://blog.csdn.net/zhaohongfei_358/article/details/126973451
#
# 论文大致内容：作者基于Transformer和BERT设计了一个多任务的网络来进行CSC（Chinese Spell Checking）任务（中文拼写纠错）。多任务分别是找出哪个字是错的和对错字进行纠正。
#
# 由于作者并没有公开代码，所以我就尝试自己实现一个，最终我的实验结果如下表：
#
# | Dataset | Model | D_Precision | D_Recall | D_F1 | C_Prec | C_Rec | C_F1 |
# |--|--|--|--|--|--|--|--|
# | SIGHAN 13 | MDCSpell | 89.1 | 78.3| 83.4 | 87.5| 76.8 | 81.8 |
# | SIGHAN 13 | MDCSpell(复现) | 80.2 | 79.9| 80.0 | 77.2| 76.9 | 77.1 |
# | SIGHAN 14 | MDCSpell | 70.2 | 68.8| 69.5 | 69.0| 67.7 | 68.3 |
# | SIGHAN 14 | MDCSpell(复现) | 82.8 | 66.6| 73.8 | 79.9| 64.3 | 71.2 |
# | SIGHAN 15 | MDCSpell | 80.8 | 80.6| 80.7 | 78.4| 78.2 | 78.3 |
# | SIGHAN 15 | MDCSpell(复现) | 86.7 | 76.1| 81.1 | 72.5| 82.7 | 77.3 |
#
# 这里是我训练了2个epoch的结果，与作者的结论相差不大。如果我增加训练次数的话，也许可以和作者的结果达到一致。

# %% [markdown]
# # 环境配置

# %%
try:
    import transformers
except:
    # !pip install transformers

# %%
import os
import copy
import pickle

import torch
import transformers

from torch import nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer
from tqdm import tqdm

# %%
torch.__version__
# Out:
# '2.0.0'

# %%
transformers.__version__
# Out:
# '4.33.0'

# %% [markdown]
# # 全局变量

# %%
# 句子的长度，作者并没有说明。我这里就按经验取一个
max_length = 256
# 作者使用的batch_size
batch_size = 32
# epoch数，作者并没有具体说明，按经验取一个
epochs = 20

# 每${log_after_step}步，打印一次日志
log_after_step = 20

# 模型存放的位置。
model_path = './drive/MyDrive/models/MDCSpell/'
os.makedirs(model_path, exist_ok=True)
model_path = model_path + 'MDCSpell-model.pt'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # 模型构建

# %% [markdown]
# <img src="asserts/images/model.png">

# %% [markdown]
# ---
#
# **Correction Network** 的数据流向如下：
#
# 1.将token序列 `[CLS] 遇 到 逆 竟 [SEP]` 送给Word Embedding模块进行embeddings，得到向量$\{e_{CLS}^w, e_1^w, e_2^w, e_3^w, e_4^w,e_{SEP}^w\}$。
#
# > 个人认为此时的embedding仅仅是Word Embeding，并不包含Position Embedding和Segment Embedding。
#
# 2.之后将$\{e_{CLS}^w, e_1^w, e_2^w, e_3^w, e_4^w,e_{SEP}^w\}$向量送入BERT，增加Position Embedding和Segment Embedding，得到 $\{e_C, e_1, e_2, e_3, e_4, e_S\}$。
#
# 3.在BERT内部，会经历多层的TransformerEncoder，最终的得到输出向量 $H^c=\{h_C^c, h_1^c, h_2^c, h_3^c, h_4^c, h_S^c\}$.
#
# 4.将BERT的输出 $H^c$ 和 隔壁Detection Network输出的 $H^d$ 进行融合，得到 $H = H^d+H^c$
#
# > 融合时并不对`[CLS]`和`[SEP]`进行融合
#
# 5.将$H$送给全连接层(Dense Layer)做最后的预测。
#
# <br>
#
# **Correction Network模型细节**：
#
# 1. **BERT**：作者使用的是具有12层Transformer Block的BERT-base版。
# 2. **Dense Layer**：Dense Layer的输入通道为词向量维度，输出通道为词典大小。例如：词向量维度为768，词典大小为20000，则Dense Layer则为`nn.Linear(768, 20000)`
# 3. **Dense Layer的初始化**：Dense Layer的权重使用的是Word Embedding的参数。因为word Embedding是将词index转成词向量，所以其参数刚好是Dense Layer的转置，即Word Embedding是`nn.Linear(20000, 768)`，所以作者就是用Word Embedding的转置来初始化Dense Layer的参数。因为这样可以加速训练，且使模型变的稳定。
#
# ---
#
# **Detection Network**的数据流向如下：
#
# 1.输入为使用BERT得到的word Embedding $\{e_1^w, e_2^w, e_3^w, e_4^w\}$。虽然图里并不包含`[CLS]`和`[SEP]`的词向量，但个人认为不需要对其特殊处理，因为最后的预测也用不到这两个token.
#
# 2.将$\{e_1^w, e_2^w, e_3^w, e_4^w\}$增加Position Embedding信息，得到$\{e_1', e_2', e_3', e_4'\}$
#
# > 在论文中说Detection Network使用的是向量$\{e_1, e_2, e_3, e_4\}$，其是word embedding+position embedding+segment embedding。这与图上是矛盾的，这里以图为准了。
#
# 3.将$\{e_1', e_2', e_3', e_4'\}$向量送入Transformer Block，得到输出向量$H^d=\{h_1^d, h_2^d, h_3^d, h_4^d\}$
#
# 4.一方面，将输出向量$H^d$送给隔壁的Correction Network进行融合；另一方面，将$H^d$送给后续的全连接层(Dense Layer)来判断哪个token是错误的.
#
# **Detection Network**的细节：
#
# 1. **Transformer Block**：Transformer Block是2层的TransformerEncoder。
# 2. **Transformer Block参数初始化**：Transformer Block参数初始化使用的是BERT的权重。
# 3. **Dense Layer**：Dense Layer的输入通道为词向量大小，输出通道为1。使用Sigmoid来判别该token为错字的概率。

# %%
class CorrectionNetwork(nn.Module):

    def __init__(self):
        super(CorrectionNetwork, self).__init__()
        # BERT分词器，作者并没提到自己使用的是哪个中文版的bert，我这里就使用一个比较常用的
        self.tokenizer = AutoTokenizer.from_pretrained("hfl/chinese-roberta-wwm-ext")
        # BERT
        self.bert = AutoModel.from_pretrained("hfl/chinese-roberta-wwm-ext")
        # BERT的word embedding，本质就是个nn.Embedding
        self.word_embedding_table = self.bert.get_input_embeddings()
        # 预测层。hidden_size是词向量的大小，len(self.tokenizer)是词典大小
        self.dense_layer = nn.Linear(self.bert.config.hidden_size, len(self.tokenizer))

    def forward(self, inputs, word_embeddings, detect_hidden_states):
        """
        Correction Network的前向传递
        :param inputs: inputs为tokenizer对中文文本的分词结果，
                       里面包含了token对一个的index，attention_mask等
        :param word_embeddings: 使用BERT的word_embedding对token进行embedding后的结果
        :param detect_hidden_states: Detection Network输出hidden state
        :return: Correction Network对个token的预测结果。
        """
        # 1. 使用bert进行前向传递
        bert_outputs = self.bert(token_type_ids=inputs['token_type_ids'],
                                 attention_mask=inputs['attention_mask'],
                                 inputs_embeds=word_embeddings)
        # 2. 将bert的hidden_state和Detection Network的hidden state进行融合。
        hidden_states = bert_outputs['last_hidden_state'] + detect_hidden_states
        # 3. 最终使用全连接层进行token预测
        return self.dense_layer(hidden_states)

    def get_inputs_and_word_embeddings(self, sequences, max_length=128):
        """
        对中文序列进行分词和word embeddings处理
        :param sequences: 中文文本序列。例如: ["鸡你太美", "哎呦，你干嘛！"]
        :param max_length: 文本的最大长度，不足则进行填充，超出进行裁剪。
        :return: tokenizer的输出和word embeddings.
        """
        inputs = self.tokenizer(sequences, padding='max_length', max_length=max_length, return_tensors='pt',
                                truncation=True).to(device)
        # 使用BERT的work embeddings对token进行embedding，这里得到的embedding并不包含position embedding和segment embedding
        word_embeddings = self.word_embedding_table(inputs['input_ids'])
        return inputs, word_embeddings

# %%
class DetectionNetwork(nn.Module):

    def __init__(self, position_embeddings, transformer_blocks, hidden_size):
        """
        :param position_embeddings: bert的position_embeddings，本质是一个nn.Embedding
        :param transformer: BERT的前两层transformer_block，其是一个ModuleList对象
        """
        super(DetectionNetwork, self).__init__()
        self.position_embeddings = position_embeddings
        self.transformer_blocks = transformer_blocks

        # 定义最后的预测层，预测哪个token是错误的
        self.dense_layer = nn.Sequential(
            nn.Linear(hidden_size, 1),
            nn.Sigmoid()
        )

    def forward(self, word_embeddings):
        # 获取token序列的长度，这里为128
        sequence_length = word_embeddings.size(1)
        # 生成position embedding
        position_embeddings = self.position_embeddings(torch.LongTensor(range(sequence_length)).to(device))
        # 融合work_embedding和position_embedding
        x = word_embeddings + position_embeddings
        # 将x一层一层的使用transformer encoder进行向后传递
        for transformer_layer in self.transformer_blocks:
            x = transformer_layer(x)[0]

        # 最终返回Detection Network输出的hidden states和预测结果
        hidden_states = x
        return hidden_states, self.dense_layer(hidden_states)

# %%
class MDCSpellModel(nn.Module):

    def __init__(self):
        super(MDCSpellModel, self).__init__()
        # 构造Correction Network
        self.correction_network = CorrectionNetwork()
        self._init_correction_dense_layer()

        # 构造Detection Network
        # position embedding使用BERT的
        position_embeddings = self.correction_network.bert.embeddings.position_embeddings
        # 作者在论文中提到的，Detection Network的Transformer使用BERT的权重
        # 所以我这里直接克隆BERT的前两层Transformer来完成这个动作
        transformer = copy.deepcopy(self.correction_network.bert.encoder.layer[:2])
        # 提取BERT的词向量大小
        hidden_size = self.correction_network.bert.config.hidden_size

        # 构造Detection Network
        self.detection_network = DetectionNetwork(position_embeddings, transformer, hidden_size)

    def forward(self, sequences, max_length=128):
        # 先获取word embedding，Correction Network和Detection Network都要用
        inputs, word_embeddings = self.correction_network.get_inputs_and_word_embeddings(sequences, max_length)
        # Detection Network进行前向传递，获取输出的Hidden State和预测结果
        hidden_states, detection_outputs = self.detection_network(word_embeddings)
        # Correction Network进行前向传递，获取其预测结果
        correction_outputs = self.correction_network(inputs, word_embeddings, hidden_states)
        # 返回Correction Network 和 Detection Network 的预测结果。
        # 在计算损失时`[PAD]`token不需要参与计算，所以这里将`[PAD]`部分全都变为0
        return correction_outputs, detection_outputs.squeeze(2) * inputs['attention_mask']

    def _init_correction_dense_layer(self):
        """
        原论文中提到，使用Word Embedding的weight来对Correction Network进行初始化
        """
        self.correction_network.dense_layer.weight.data = self.correction_network.word_embedding_table.weight.data

# %% [markdown]
# 定义好模型后，我们来简单的尝试一下：

# %%
model = MDCSpellModel().to(device)
correction_outputs, detection_outputs = model(["鸡你太美", "哎呦，你干嘛！"])
print("correction_outputs shape:", correction_outputs.size())
print("detection_outputs shape:", detection_outputs.size())
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Downloading pytorch_model.bin:   0%|          | 0.00/412M [00:00<?, ?B/s]
# correction_outputs shape: torch.Size([2, 128, 21128])
# detection_outputs shape: torch.Size([2, 128])

# %% [markdown]
# # 损失函数

# %% [markdown]
# Correction Network和Detection Network使用的都是Cross Entropy。之后进行相加即可：
#
# $$
# L = \lambda L^c + (1-\lambda) L^d
# $$
#
# 其中 $\lambda \in [0,1]$ 。作者通过实验得出 $\lambda=0.85$ 时效果最好。

# %%
class MDCSpellLoss(nn.Module):

    def __init__(self, coefficient=0.85):
        super(MDCSpellLoss, self).__init__()
        # 定义Correction Network的Loss函数
        self.correction_criterion = nn.CrossEntropyLoss(ignore_index=0)
        # 定义Detection Network的Loss函数，因为是二分类，所以用Binary Cross Entropy
        self.detection_criterion = nn.BCELoss()
        # 权重系数
        self.coefficient = coefficient

    def forward(self, correction_outputs, correction_targets, detection_outputs, detection_targets):
        """
        :param correction_outputs: Correction Network的输出，Shape为(batch_size, sequence_length, hidden_size)
        :param correction_targets: Correction Network的标签，Shape为(batch_size, sequence_length)
        :param detection_outputs: Detection Network的输出，Shape为(batch_size, sequence_length)
        :param detection_targets: Detection Network的标签，Shape为(batch_size, sequence_length)
        :return:
        """
        # 计算Correction Network的loss，因为Shape维度为3，所以要把batch_size和sequence_length进行合并才能计算
        correction_loss = self.correction_criterion(correction_outputs.view(-1, correction_outputs.size(2)),
                                                    correction_targets.view(-1))
        # 计算Detection Network的loss
        detection_loss = self.detection_criterion(detection_outputs, detection_targets)
        # 对两个loss进行加权平均
        return self.coefficient * correction_loss + (1 - self.coefficient) * detection_loss

# %% [markdown]
# # 模型训练

# %% [markdown]
# 作者的训练方式：
#
# 1. 第一步，首先使用 [Wang271K(自己造的假数据)](https://github.com/wdimmy/Automatic-Corpus-Generation) 数据集进行训练。batch size为32， learning rate为2e-5
#
# 2. 第二步，使用SIGHAN训练集进行fine-tune。 batch size为32，learning rate为1e-5
#
# > 作者并没有提到使用的是什么Optimizer，但看这个学习率，应该是Adam。
#
# > 在第一步，作者说的是使用了几乎3M个，但作者只提到过Wang271K这个数据集，我猜可能作者看错了，这个是0.3M条数据，而不是3M。

# %% [markdown]
# 作者首先使用了Wang271K数据集进行对模型进行训练，然后又使用SIGHAN训练集对模型进行fine-tune。这里我就不进行fine-tune了，直接进行训练。我这里使用的是 [ReaLiSe](https://github.com/DaDaMrX/ReaLiSe)论文 处理好的数据集，其就是Wang271K和SIGHAN。
#
# [百度网盘链接](https://pan.baidu.com/s/1x67LPiYAjLKhO1_2CI6aOA?pwd=skda) ：https://pan.baidu.com/s/1x67LPiYAjLKhO1_2CI6aOA?pwd=skda
#
# 下载好直接解压即可。

# %% [markdown]
# ## 构造Dataset

# %%
import pandas as pd
punctuation = """.,!?"'。？！，、；：“”‘’《》（）【】—…￥"""
punctuation = list(punctuation)
class CSCDataset(Dataset):

    def __init__(self, path):
        super(CSCDataset, self).__init__()
        df = pd.read_csv(path, sep='\t', header=None)
        srcs = df[1]
        tgts = df[2]
        self.data = list(zip(srcs, tgts))

    def __getitem__(self, index):
        src = self.data[index][0]
        tgt = self.data[index][1]
        if src[-1] not in punctuation:
            src += '。'
        if tgt[-1] not in punctuation:
            tgt += '。'
        return src, tgt

    def __len__(self):
        return len(self.data)

# %%
train_data = CSCDataset("/kaggle/input/cscd-ime/train.tsv")

# %%
train_data.__getitem__(0)
# Out:
# ('市疾控中心发布新近“社区登革热疫情应急控制指引”，加强对社区防控登革热的技术指导。',
#  '市疾控中心发布新近“社区登革热疫情应急控制指引”，加强对社区防控登革热的技术指导。')

# %% [markdown]
# ## 构造Dataloader

# %%
tokenizer = AutoTokenizer.from_pretrained("hfl/chinese-roberta-wwm-ext")

# %%
def collate_fn(batch):
    src, tgt = zip(*batch)
    src, tgt = list(src), list(tgt)

    src_tokens = tokenizer(src, padding='max_length', max_length=128, return_tensors='pt', truncation=True)['input_ids']
    tgt_tokens = tokenizer(tgt, padding='max_length', max_length=128, return_tensors='pt', truncation=True)['input_ids']

    correction_targets = tgt_tokens
    detection_targets = (src_tokens != tgt_tokens).float()
    return src, correction_targets, detection_targets, src_tokens  # src_tokens在计算Correction的精准率时要用到

# %%
train_loader = DataLoader(train_data, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)

# %% [markdown]
# ## 训练

# %%
criterion = MDCSpellLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-5)
start_epoch = 0  # 从哪个epoch开始
total_step = 0  # 一共更新了多少次参数

# %%
# 恢复之前的训练
if os.path.exists(model_path):
    if not torch.cuda.is_available():
        checkpoint = torch.load(model_path, map_location='cpu')
    else:
        checkpoint = torch.load(model_path)
    model.load_state_dict(checkpoint['model'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_epoch = checkpoint['epoch']
    total_step = checkpoint['total_step']
    print("恢复训练，epoch:", start_epoch)

# %%
model = model.to(device)
model = model.train()

# %% [markdown]
# 训练这里代码量看起来很大，但实际大多都是计算recall和precision的代码。这里对于Detection的recall和precision的计算使用的是Detection Network的预测结果。

# %%
total_loss = 0.  # 记录loss

d_recall_numerator = 0  # Detection的Recall的分子
d_recall_denominator = 0  # Detection的Recall的分母
d_precision_numerator = 0  # Detection的precision的分子
d_precision_denominator = 0  # Detection的precision的分母
c_recall_numerator = 0  # Correction的Recall的分子
c_recall_denominator = 0  # Correction的Recall的分母
c_precision_numerator = 0  # Correction的precision的分子
c_precision_denominator = 0  # Correction的precision的分母

for epoch in range(start_epoch, epochs):

    step = 0

    for sequences, correction_targets, detection_targets, correction_inputs in train_loader:
        correction_targets, detection_targets = correction_targets.to(device), detection_targets.to(device)
        correction_inputs = correction_inputs.to(device)
        correction_outputs, detection_outputs = model(sequences)
        loss = criterion(correction_outputs, correction_targets, detection_outputs, detection_targets)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        step += 1
        total_step += 1

        total_loss += loss.detach().item()

        # 计算Detection的recall和precision指标
        # 大于0.5，认为是错误token，反之为正确token
        d_predicts = detection_outputs >= 0.5
        # 计算错误token中被网络正确预测到的数量
        d_recall_numerator += d_predicts[detection_targets == 1].sum().item()
        # 计算错误token的数量
        d_recall_denominator += (detection_targets == 1).sum().item()
        # 计算网络预测的错误token的数量
        d_precision_denominator += d_predicts.sum().item()
        # 计算网络预测的错误token中，有多少是真错误的token
        d_precision_numerator += (detection_targets[d_predicts == 1]).sum().item()

        # 计算Correction的recall和precision
        # 将输出映射成index，即将correction_outputs的Shape由(32, 128, 21128)变为(32,128)
        correction_outputs = correction_outputs.argmax(2)
        # 对于填充、[CLS]和[SEP]这三个token不校验
        correction_outputs[(correction_targets == 0) | (correction_targets == 101) | (correction_targets == 102)] = 0
        # correction_targets的[CLS]和[SEP]也要变为0
        correction_targets[(correction_targets == 101) | (correction_targets == 102)] = 0
        # Correction的预测结果，其中True表示预测正确，False表示预测错误或无需预测
        c_predicts = correction_outputs == correction_targets
        # 计算错误token中被网络正确纠正的token数量
        c_recall_numerator += c_predicts[detection_targets == 1].sum().item()
        # 计算错误token的数量
        c_recall_denominator += (detection_targets == 1).sum().item()
        # 计算网络纠正token的数量
        correction_inputs[(correction_inputs == 101) | (correction_inputs == 102)] = 0
        c_precision_denominator += (correction_outputs != correction_inputs).sum().item()
        # 计算在网络纠正的这些token中，有多少是真正被纠正对的
        c_precision_numerator += c_predicts[correction_outputs != correction_inputs].sum().item()

        if total_step % log_after_step == 0:
            loss = total_loss / log_after_step
            d_recall = d_recall_numerator / (d_recall_denominator + 1e-9)
            d_precision = d_precision_numerator / (d_precision_denominator + 1e-9)
            c_recall = c_recall_numerator / (c_recall_denominator + 1e-9)
            c_precision = c_precision_numerator / (c_precision_denominator + 1e-9)

            print("Epoch {}, "
                  "Step {}/{}, "
                  "Total Step {}, "
                  "loss {:.5f}, "
                  "detection recall {:.4f}, "
                  "detection precision {:.4f}, "
                  "correction recall {:.4f}, "
                  "correction precision {:.4f}".format(epoch, step, len(train_loader), total_step,
                                                       loss,
                                                       d_recall,
                                                       d_precision,
                                                       c_recall,
                                                       c_precision))

            total_loss = 0.
            total_correct = 0
            total_num = 0
            d_recall_numerator = 0
            d_recall_denominator = 0
            d_precision_numerator = 0
            d_precision_denominator = 0
            c_recall_numerator = 0
            c_recall_denominator = 0
            c_precision_numerator = 0
            c_precision_denominator = 0

    torch.save({
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'epoch': epoch + 1,
        'total_step': total_step,
    }, model_path)
# Out:
# Epoch 0, Step 20/938, Total Step 20, loss 0.66714, detection recall 0.0000, detection precision 0.0000, correction recall 0.0000, correction precision 0.0000
# Epoch 0, Step 40/938, Total Step 40, loss 0.14725, detection recall 0.0000, detection precision 0.0000, correction recall 0.0000, correction precision 0.0000
# Epoch 0, Step 60/938, Total Step 60, loss 0.12281, detection recall 0.0000, detection precision 0.0000, correction recall 0.0000, correction precision 0.0000
# Epoch 0, Step 80/938, Total Step 80, loss 0.10559, detection recall 0.0000, detection precision 0.0000, correction recall 0.0096, correction precision 0.2308
# Epoch 0, Step 100/938, Total Step 100, loss 0.10185, detection recall 0.0000, detection precision 0.0000, correction recall 0.0060, correction precision 0.2500
# Epoch 0, Step 120/938, Total Step 120, loss 0.09730, detection recall 0.0000, detection precision 0.0000, correction recall 0.0151, correction precision 0.2941
# Epoch 0, Step 140/938, Total Step 140, loss 0.08821, detection recall 0.0000, detection precision 0.0000, correction recall 0.0318, correction precision 0.4762
# Epoch 0, Step 160/938, Total Step 160, loss 0.08968, detection recall 0.0000, detection precision 0.0000, correction recall 0.0151, correction precision 0.3333
# Epoch 0, Step 180/938, Total Step 180, loss 0.08411, detection recall 0.0000, detection precision 0.0000, correction recall 0.0273, correction precision 0.3214
# Epoch 0, Step 200/938, Total Step 200, loss 0.08249, detection recall 0.0000, detection precision 0.0000, correction recall 0.0248, correction precision 0.2222
# Epoch 0, Step 220/938, Total Step 220, loss 0.07638, detection recall 0.0000, detection precision 0.0000, correction recall 0.0415, correction precision 0.3415
# Epoch 0, Step 240/938, Total Step 240, loss 0.07899, detection recall 0.0000, detection precision 0.0000, correction recall 0.0186, correction precision 0.1667
# Epoch 0, Step 260/938, Total Step 260, loss 0.07461, detection recall 0.0000, detection precision 0.0000, correction recall 0.0290, correction precision 0.4286
# Epoch 0, Step 280/938, Total Step 280, loss 0.06907, detection recall 0.0000, detection precision 0.0000, correction recall 0.0312, correction precision 0.4545
# Epoch 0, Step 300/938, Total Step 300, loss 0.06966, detection recall 0.0000, detection precision 0.0000, correction recall 0.0607, correction precision 0.6129
# Epoch 0, Step 320/938, Total Step 320, loss 0.06801, detection recall 0.0000, detection precision 0.0000, correction recall 0.0457, correction precision 0.6000
# Epoch 0, Step 340/938, Total Step 340, loss 0.07042, detection recall 0.0000, detection precision 0.0000, correction recall 0.0404, correction precision 0.5000
# Epoch 0, Step 360/938, Total Step 360, loss 0.06659, detection recall 0.0000, detection precision 0.0000, correction recall 0.0452, correction precision 0.6667
# Epoch 0, Step 380/938, Total Step 380, loss 0.06436, detection recall 0.0000, detection precision 0.0000, correction recall 0.0615, correction precision 0.7308
# Epoch 0, Step 400/938, Total Step 400, loss 0.06575, detection recall 0.0000, detection precision 0.0000, correction recall 0.0861, correction precision 0.8286
# Epoch 0, Step 420/938, Total Step 420, loss 0.06986, detection recall 0.0000, detection precision 0.0000, correction recall 0.0469, correction precision 0.6667
# Epoch 0, Step 440/938, Total Step 440, loss 0.06376, detection recall 0.0000, detection precision 0.0000, correction recall 0.0844, correction precision 0.6750
# Epoch 0, Step 460/938, Total Step 460, loss 0.06591, detection recall 0.0000, detection precision 0.0000, correction recall 0.0550, correction precision 0.6207
# Epoch 0, Step 480/938, Total Step 480, loss 0.05752, detection recall 0.0000, detection precision 0.0000, correction recall 0.0728, correction precision 0.6875
# Epoch 0, Step 500/938, Total Step 500, loss 0.06362, detection recall 0.0000, detection precision 0.0000, correction recall 0.0870, correction precision 0.7368
# Epoch 0, Step 520/938, Total Step 520, loss 0.05608, detection recall 0.0000, detection precision 0.0000, correction recall 0.1047, correction precision 0.7381
# Epoch 0, Step 540/938, Total Step 540, loss 0.06328, detection recall 0.0000, detection precision 0.0000, correction recall 0.0726, correction precision 0.7931
# Epoch 0, Step 560/938, Total Step 560, loss 0.05867, detection recall 0.0000, detection precision 0.0000, correction recall 0.0889, correction precision 0.8000
# Epoch 0, Step 580/938, Total Step 580, loss 0.06106, detection recall 0.0000, detection precision 0.0000, correction recall 0.1012, correction precision 0.7674
# Epoch 0, Step 600/938, Total Step 600, loss 0.06488, detection recall 0.0000, detection precision 0.0000, correction recall 0.1190, correction precision 0.7636
# Epoch 0, Step 620/938, Total Step 620, loss 0.05770, detection recall 0.0000, detection precision 0.0000, correction recall 0.1329, correction precision 0.8750
# Epoch 0, Step 640/938, Total Step 640, loss 0.06390, detection recall 0.0000, detection precision 0.0000, correction recall 0.1243, correction precision 0.8113
# Epoch 0, Step 660/938, Total Step 660, loss 0.05483, detection recall 0.0000, detection precision 0.0000, correction recall 0.1375, correction precision 0.8800
# Epoch 0, Step 680/938, Total Step 680, loss 0.06086, detection recall 0.0000, detection precision 0.0000, correction recall 0.1082, correction precision 0.7872
# Epoch 0, Step 700/938, Total Step 700, loss 0.05251, detection recall 0.0000, detection precision 0.0000, correction recall 0.1204, correction precision 0.7826
# Epoch 0, Step 720/938, Total Step 720, loss 0.05786, detection recall 0.0000, detection precision 0.0000, correction recall 0.1064, correction precision 0.7778
# Epoch 0, Step 740/938, Total Step 740, loss 0.05192, detection recall 0.0000, detection precision 0.0000, correction recall 0.1269, correction precision 0.8913
# Epoch 0, Step 760/938, Total Step 760, loss 0.05229, detection recall 0.0000, detection precision 0.0000, correction recall 0.1415, correction precision 0.9184
# Epoch 0, Step 780/938, Total Step 780, loss 0.05470, detection recall 0.0000, detection precision 0.0000, correction recall 0.1498, correction precision 0.8750
# Epoch 0, Step 800/938, Total Step 800, loss 0.05289, detection recall 0.0000, detection precision 0.0000, correction recall 0.1411, correction precision 0.8491
# Epoch 0, Step 820/938, Total Step 820, loss 0.05359, detection recall 0.0000, detection precision 0.0000, correction recall 0.1508, correction precision 0.8305
# Epoch 0, Step 840/938, Total Step 840, loss 0.05378, detection recall 0.0000, detection precision 0.0000, correction recall 0.1734, correction precision 0.8615
# Epoch 0, Step 860/938, Total Step 860, loss 0.05516, detection recall 0.0000, detection precision 0.0000, correction recall 0.1345, correction precision 0.8846
# Epoch 0, Step 880/938, Total Step 880, loss 0.05320, detection recall 0.0000, detection precision 0.0000, correction recall 0.1576, correction precision 0.8667
# Epoch 0, Step 900/938, Total Step 900, loss 0.04930, detection recall 0.0000, detection precision 0.0000, correction recall 0.2006, correction precision 0.8649
# Epoch 0, Step 920/938, Total Step 920, loss 0.04892, detection recall 0.0000, detection precision 0.0000, correction recall 0.1640, correction precision 0.9273
# Epoch 1, Step 2/938, Total Step 940, loss 0.05312, detection recall 0.0000, detection precision 0.0000, correction recall 0.1506, correction precision 0.8929
# Epoch 1, Step 22/938, Total Step 960, loss 0.04030, detection recall 0.0000, detection precision 0.0000, correction recall 0.2318, correction precision 0.8434
# Epoch 1, Step 42/938, Total Step 980, loss 0.04441, detection recall 0.0000, detection precision 0.0000, correction recall 0.2326, correction precision 0.8953
# Epoch 1, Step 62/938, Total Step 1000, loss 0.04412, detection recall 0.0000, detection precision 0.0000, correction recall 0.2484, correction precision 0.8587
# Epoch 1, Step 82/938, Total Step 1020, loss 0.04259, detection recall 0.0000, detection precision 0.0000, correction recall 0.2267, correction precision 0.8795
# Epoch 1, Step 102/938, Total Step 1040, loss 0.04764, detection recall 0.0000, detection precision 0.0000, correction recall 0.1921, correction precision 0.9403
# Epoch 1, Step 122/938, Total Step 1060, loss 0.04473, detection recall 0.0000, detection precision 0.0000, correction recall 0.2334, correction precision 0.8409
# Epoch 1, Step 142/938, Total Step 1080, loss 0.04092, detection recall 0.0000, detection precision 0.0000, correction recall 0.1759, correction precision 0.8437
# Epoch 1, Step 162/938, Total Step 1100, loss 0.04443, detection recall 0.0000, detection precision 0.0000, correction recall 0.2545, correction precision 0.8673
# Epoch 1, Step 182/938, Total Step 1120, loss 0.03950, detection recall 0.0000, detection precision 0.0000, correction recall 0.2339, correction precision 0.9079
# Epoch 1, Step 202/938, Total Step 1140, loss 0.04163, detection recall 0.0000, detection precision 0.0000, correction recall 0.2244, correction precision 0.8974
# Epoch 1, Step 222/938, Total Step 1160, loss 0.05037, detection recall 0.0000, detection precision 0.0000, correction recall 0.1850, correction precision 0.8649
# Epoch 1, Step 242/938, Total Step 1180, loss 0.04446, detection recall 0.0000, detection precision 0.0000, correction recall 0.2735, correction precision 0.8205
# Epoch 1, Step 262/938, Total Step 1200, loss 0.04519, detection recall 0.0000, detection precision 0.0000, correction recall 0.2255, correction precision 0.8444
# Epoch 1, Step 282/938, Total Step 1220, loss 0.04265, detection recall 0.0000, detection precision 0.0000, correction recall 0.2470, correction precision 0.8804
# Epoch 1, Step 302/938, Total Step 1240, loss 0.04273, detection recall 0.0000, detection precision 0.0000, correction recall 0.2590, correction precision 0.9053
# Epoch 1, Step 322/938, Total Step 1260, loss 0.03898, detection recall 0.0000, detection precision 0.0000, correction recall 0.2278, correction precision 0.8780
# Epoch 1, Step 342/938, Total Step 1280, loss 0.04166, detection recall 0.0000, detection precision 0.0000, correction recall 0.2507, correction precision 0.8750
# Epoch 1, Step 362/938, Total Step 1300, loss 0.03929, detection recall 0.0000, detection precision 0.0000, correction recall 0.2767, correction precision 0.9167
# Epoch 1, Step 382/938, Total Step 1320, loss 0.04005, detection recall 0.0000, detection precision 0.0000, correction recall 0.2683, correction precision 0.8224
# Epoch 1, Step 402/938, Total Step 1340, loss 0.03847, detection recall 0.0000, detection precision 0.0000, correction recall 0.2771, correction precision 0.8598
# Epoch 1, Step 422/938, Total Step 1360, loss 0.04258, detection recall 0.0000, detection precision 0.0000, correction recall 0.2661, correction precision 0.8585
# Epoch 1, Step 442/938, Total Step 1380, loss 0.03999, detection recall 0.0000, detection precision 0.0000, correction recall 0.2145, correction precision 0.7391
# Epoch 1, Step 462/938, Total Step 1400, loss 0.03970, detection recall 0.0000, detection precision 0.0000, correction recall 0.2553, correction precision 0.8252
# Epoch 1, Step 482/938, Total Step 1420, loss 0.03959, detection recall 0.0000, detection precision 0.0000, correction recall 0.2477, correction precision 0.8617
# Epoch 1, Step 502/938, Total Step 1440, loss 0.03826, detection recall 0.0000, detection precision 0.0000, correction recall 0.2848, correction precision 0.8381
# Epoch 1, Step 522/938, Total Step 1460, loss 0.04003, detection recall 0.0000, detection precision 0.0000, correction recall 0.2818, correction precision 0.8230
# Epoch 1, Step 542/938, Total Step 1480, loss 0.03921, detection recall 0.0000, detection precision 0.0000, correction recall 0.2894, correction precision 0.8738
# Epoch 1, Step 562/938, Total Step 1500, loss 0.03872, detection recall 0.0000, detection precision 0.0000, correction recall 0.2524, correction precision 0.8667
# Epoch 1, Step 582/938, Total Step 1520, loss 0.04195, detection recall 0.0000, detection precision 0.0000, correction recall 0.2836, correction precision 0.8716
# Epoch 1, Step 602/938, Total Step 1540, loss 0.03993, detection recall 0.0000, detection precision 0.0000, correction recall 0.2580, correction precision 0.8020
# Epoch 1, Step 622/938, Total Step 1560, loss 0.03733, detection recall 0.0000, detection precision 0.0000, correction recall 0.2701, correction precision 0.8842
# Epoch 1, Step 642/938, Total Step 1580, loss 0.03927, detection recall 0.0000, detection precision 0.0000, correction recall 0.2776, correction precision 0.8713
# Epoch 1, Step 662/938, Total Step 1600, loss 0.04000, detection recall 0.0000, detection precision 0.0000, correction recall 0.2736, correction precision 0.7925
# Epoch 1, Step 682/938, Total Step 1620, loss 0.03712, detection recall 0.0000, detection precision 0.0000, correction recall 0.2708, correction precision 0.8125
# Epoch 1, Step 702/938, Total Step 1640, loss 0.03688, detection recall 0.0000, detection precision 0.0000, correction recall 0.3103, correction precision 0.9167
# Epoch 1, Step 722/938, Total Step 1660, loss 0.03636, detection recall 0.0000, detection precision 0.0000, correction recall 0.3019, correction precision 0.8136
# Epoch 1, Step 742/938, Total Step 1680, loss 0.04173, detection recall 0.0000, detection precision 0.0000, correction recall 0.2746, correction precision 0.8519
# Epoch 1, Step 762/938, Total Step 1700, loss 0.03734, detection recall 0.0000, detection precision 0.0000, correction recall 0.3240, correction precision 0.8889
# Epoch 1, Step 782/938, Total Step 1720, loss 0.04124, detection recall 0.0000, detection precision 0.0000, correction recall 0.2841, correction precision 0.8870
# Epoch 1, Step 802/938, Total Step 1740, loss 0.04186, detection recall 0.0000, detection precision 0.0000, correction recall 0.2372, correction precision 0.7551
# Epoch 1, Step 822/938, Total Step 1760, loss 0.03690, detection recall 0.0000, detection precision 0.0000, correction recall 0.3000, correction precision 0.8761
# Epoch 1, Step 842/938, Total Step 1780, loss 0.03867, detection recall 0.0000, detection precision 0.0000, correction recall 0.2884, correction precision 0.8762
# Epoch 1, Step 862/938, Total Step 1800, loss 0.03494, detection recall 0.0000, detection precision 0.0000, correction recall 0.3222, correction precision 0.8760
# Epoch 1, Step 882/938, Total Step 1820, loss 0.03912, detection recall 0.0000, detection precision 0.0000, correction recall 0.3195, correction precision 0.8710
# Epoch 1, Step 902/938, Total Step 1840, loss 0.03466, detection recall 0.0000, detection precision 0.0000, correction recall 0.3333, correction precision 0.8548
# Epoch 1, Step 922/938, Total Step 1860, loss 0.04026, detection recall 0.0000, detection precision 0.0000, correction recall 0.2997, correction precision 0.8829
# Epoch 2, Step 4/938, Total Step 1880, loss 0.03285, detection recall 0.0000, detection precision 0.0000, correction recall 0.3398, correction precision 0.8607
# Epoch 2, Step 24/938, Total Step 1900, loss 0.03093, detection recall 0.0000, detection precision 0.0000, correction recall 0.3365, correction precision 0.9145
# Epoch 2, Step 44/938, Total Step 1920, loss 0.02731, detection recall 0.0000, detection precision 0.0000, correction recall 0.4526, correction precision 0.9136
# Epoch 2, Step 64/938, Total Step 1940, loss 0.02962, detection recall 0.0000, detection precision 0.0000, correction recall 0.3670, correction precision 0.8696
# Epoch 2, Step 84/938, Total Step 1960, loss 0.02901, detection recall 0.0000, detection precision 0.0000, correction recall 0.3705, correction precision 0.8849
# Epoch 2, Step 104/938, Total Step 1980, loss 0.02927, detection recall 0.0000, detection precision 0.0000, correction recall 0.4085, correction precision 0.8816
# Epoch 2, Step 124/938, Total Step 2000, loss 0.02743, detection recall 0.0000, detection precision 0.0000, correction recall 0.4177, correction precision 0.8302
# Epoch 2, Step 144/938, Total Step 2020, loss 0.02946, detection recall 0.0000, detection precision 0.0000, correction recall 0.4206, correction precision 0.8940
# Epoch 2, Step 164/938, Total Step 2040, loss 0.02919, detection recall 0.0000, detection precision 0.0000, correction recall 0.3885, correction precision 0.9173
# Epoch 2, Step 184/938, Total Step 2060, loss 0.02592, detection recall 0.0000, detection precision 0.0000, correction recall 0.4083, correction precision 0.9147
# Epoch 2, Step 204/938, Total Step 2080, loss 0.02761, detection recall 0.0000, detection precision 0.0000, correction recall 0.3981, correction precision 0.8993
# Epoch 2, Step 224/938, Total Step 2100, loss 0.02921, detection recall 0.0000, detection precision 0.0000, correction recall 0.4320, correction precision 0.8667
# Epoch 2, Step 244/938, Total Step 2120, loss 0.02852, detection recall 0.0000, detection precision 0.0000, correction recall 0.4026, correction precision 0.8794
# Epoch 2, Step 264/938, Total Step 2140, loss 0.02510, detection recall 0.0000, detection precision 0.0000, correction recall 0.4471, correction precision 0.8792
# Epoch 2, Step 284/938, Total Step 2160, loss 0.02843, detection recall 0.0000, detection precision 0.0000, correction recall 0.3754, correction precision 0.8881
# Epoch 2, Step 304/938, Total Step 2180, loss 0.02809, detection recall 0.0000, detection precision 0.0000, correction recall 0.3976, correction precision 0.8497
# Epoch 2, Step 324/938, Total Step 2200, loss 0.02713, detection recall 0.0000, detection precision 0.0000, correction recall 0.3705, correction precision 0.8433
# Epoch 2, Step 344/938, Total Step 2220, loss 0.03163, detection recall 0.0000, detection precision 0.0000, correction recall 0.3798, correction precision 0.8258
# Epoch 2, Step 364/938, Total Step 2240, loss 0.02662, detection recall 0.0000, detection precision 0.0000, correction recall 0.4190, correction precision 0.9041
# Epoch 2, Step 384/938, Total Step 2260, loss 0.02773, detection recall 0.0000, detection precision 0.0000, correction recall 0.4085, correction precision 0.8816
# Epoch 2, Step 404/938, Total Step 2280, loss 0.02637, detection recall 0.0000, detection precision 0.0000, correction recall 0.4465, correction precision 0.8690
# Epoch 2, Step 424/938, Total Step 2300, loss 0.02942, detection recall 0.0000, detection precision 0.0000, correction recall 0.3834, correction precision 0.8929
# Epoch 2, Step 444/938, Total Step 2320, loss 0.02737, detection recall 0.0000, detection precision 0.0000, correction recall 0.4693, correction precision 0.8844
# Epoch 2, Step 464/938, Total Step 2340, loss 0.02911, detection recall 0.0000, detection precision 0.0000, correction recall 0.4615, correction precision 0.9017
# Epoch 2, Step 484/938, Total Step 2360, loss 0.02737, detection recall 0.0000, detection precision 0.0000, correction recall 0.4196, correction precision 0.9216
# Epoch 2, Step 504/938, Total Step 2380, loss 0.02292, detection recall 0.0000, detection precision 0.0000, correction recall 0.4281, correction precision 0.8414
# Epoch 2, Step 524/938, Total Step 2400, loss 0.02806, detection recall 0.0000, detection precision 0.0000, correction recall 0.4172, correction precision 0.8452
# Epoch 2, Step 544/938, Total Step 2420, loss 0.02828, detection recall 0.0000, detection precision 0.0000, correction recall 0.4273, correction precision 0.9187
# Epoch 2, Step 564/938, Total Step 2440, loss 0.02947, detection recall 0.0000, detection precision 0.0000, correction recall 0.4211, correction precision 0.8889
# Epoch 2, Step 584/938, Total Step 2460, loss 0.02872, detection recall 0.0000, detection precision 0.0000, correction recall 0.4019, correction precision 0.8699
# Epoch 2, Step 604/938, Total Step 2480, loss 0.02583, detection recall 0.0000, detection precision 0.0000, correction recall 0.4512, correction precision 0.8268
# Epoch 2, Step 624/938, Total Step 2500, loss 0.02826, detection recall 0.0000, detection precision 0.0000, correction recall 0.4665, correction precision 0.8163
# Epoch 2, Step 644/938, Total Step 2520, loss 0.02984, detection recall 0.0000, detection precision 0.0000, correction recall 0.4074, correction precision 0.8250
# Epoch 2, Step 664/938, Total Step 2540, loss 0.02931, detection recall 0.0000, detection precision 0.0000, correction recall 0.4530, correction precision 0.9086
# Epoch 2, Step 684/938, Total Step 2560, loss 0.02582, detection recall 0.0000, detection precision 0.0000, correction recall 0.4522, correction precision 0.8659
# Epoch 2, Step 704/938, Total Step 2580, loss 0.02311, detection recall 0.0000, detection precision 0.0000, correction recall 0.4788, correction precision 0.8802
# Epoch 2, Step 724/938, Total Step 2600, loss 0.02919, detection recall 0.0000, detection precision 0.0000, correction recall 0.4161, correction precision 0.8758
# Epoch 2, Step 744/938, Total Step 2620, loss 0.02910, detection recall 0.0000, detection precision 0.0000, correction recall 0.4054, correction precision 0.9060
# Epoch 2, Step 764/938, Total Step 2640, loss 0.02504, detection recall 0.0000, detection precision 0.0000, correction recall 0.4337, correction precision 0.8121
# Epoch 2, Step 784/938, Total Step 2660, loss 0.02522, detection recall 0.0000, detection precision 0.0000, correction recall 0.4923, correction precision 0.9138
# Epoch 2, Step 804/938, Total Step 2680, loss 0.02497, detection recall 0.0000, detection precision 0.0000, correction recall 0.4314, correction precision 0.8627
# Epoch 2, Step 824/938, Total Step 2700, loss 0.02540, detection recall 0.0000, detection precision 0.0000, correction recall 0.4355, correction precision 0.8385
# Epoch 2, Step 844/938, Total Step 2720, loss 0.02236, detection recall 0.0000, detection precision 0.0000, correction recall 0.4936, correction precision 0.8908
# Epoch 2, Step 864/938, Total Step 2740, loss 0.02849, detection recall 0.0000, detection precision 0.0000, correction recall 0.4194, correction precision 0.8314
# Epoch 2, Step 884/938, Total Step 2760, loss 0.02919, detection recall 0.0000, detection precision 0.0000, correction recall 0.4274, correction precision 0.8621
# Epoch 2, Step 904/938, Total Step 2780, loss 0.02868, detection recall 0.0000, detection precision 0.0000, correction recall 0.4566, correction precision 0.8495
# Epoch 2, Step 924/938, Total Step 2800, loss 0.02759, detection recall 0.0000, detection precision 0.0000, correction recall 0.4141, correction precision 0.8654
# Epoch 3, Step 6/938, Total Step 2820, loss 0.02468, detection recall 0.0000, detection precision 0.0000, correction recall 0.5000, correction precision 0.9080
# Epoch 3, Step 26/938, Total Step 2840, loss 0.02103, detection recall 0.0000, detection precision 0.0000, correction recall 0.5342, correction precision 0.8776
# Epoch 3, Step 46/938, Total Step 2860, loss 0.01797, detection recall 0.0000, detection precision 0.0000, correction recall 0.5724, correction precision 0.8878
# Epoch 3, Step 66/938, Total Step 2880, loss 0.02220, detection recall 0.0000, detection precision 0.0000, correction recall 0.5702, correction precision 0.9653
# Epoch 3, Step 86/938, Total Step 2900, loss 0.02182, detection recall 0.0000, detection precision 0.0000, correction recall 0.5478, correction precision 0.9130
# Epoch 3, Step 106/938, Total Step 2920, loss 0.02047, detection recall 0.0000, detection precision 0.0000, correction recall 0.5752, correction precision 0.8705
# Epoch 3, Step 126/938, Total Step 2940, loss 0.01907, detection recall 0.0000, detection precision 0.0000, correction recall 0.5112, correction precision 0.9195
# Epoch 3, Step 146/938, Total Step 2960, loss 0.02037, detection recall 0.0000, detection precision 0.0000, correction recall 0.5667, correction precision 0.8821
# Epoch 3, Step 166/938, Total Step 2980, loss 0.02139, detection recall 0.0000, detection precision 0.0000, correction recall 0.5367, correction precision 0.8971
# Epoch 3, Step 186/938, Total Step 3000, loss 0.01761, detection recall 0.0000, detection precision 0.0000, correction recall 0.5590, correction precision 0.9306
# Epoch 3, Step 206/938, Total Step 3020, loss 0.01758, detection recall 0.0000, detection precision 0.0000, correction recall 0.5687, correction precision 0.9055
# Epoch 3, Step 226/938, Total Step 3040, loss 0.01914, detection recall 0.0000, detection precision 0.0000, correction recall 0.5194, correction precision 0.9110
# Epoch 3, Step 246/938, Total Step 3060, loss 0.02006, detection recall 0.0000, detection precision 0.0000, correction recall 0.5588, correction precision 0.8597
# Epoch 3, Step 266/938, Total Step 3080, loss 0.01880, detection recall 0.0000, detection precision 0.0000, correction recall 0.5288, correction precision 0.8667
# Epoch 3, Step 286/938, Total Step 3100, loss 0.02021, detection recall 0.0000, detection precision 0.0000, correction recall 0.5476, correction precision 0.9200
# Epoch 3, Step 306/938, Total Step 3120, loss 0.02054, detection recall 0.0000, detection precision 0.0000, correction recall 0.5463, correction precision 0.8985
# Epoch 3, Step 326/938, Total Step 3140, loss 0.01916, detection recall 0.0000, detection precision 0.0000, correction recall 0.6168, correction precision 0.9083
# Epoch 3, Step 346/938, Total Step 3160, loss 0.02007, detection recall 0.0000, detection precision 0.0000, correction recall 0.5956, correction precision 0.8597
# Epoch 3, Step 366/938, Total Step 3180, loss 0.02080, detection recall 0.0000, detection precision 0.0000, correction recall 0.5599, correction precision 0.9054
# Epoch 3, Step 386/938, Total Step 3200, loss 0.01762, detection recall 0.0000, detection precision 0.0000, correction recall 0.5897, correction precision 0.9246
# Epoch 3, Step 406/938, Total Step 3220, loss 0.01849, detection recall 0.0000, detection precision 0.0000, correction recall 0.5836, correction precision 0.9113
# Epoch 3, Step 426/938, Total Step 3240, loss 0.02107, detection recall 0.0000, detection precision 0.0000, correction recall 0.5165, correction precision 0.8776
# Epoch 3, Step 446/938, Total Step 3260, loss 0.01806, detection recall 0.0000, detection precision 0.0000, correction recall 0.5974, correction precision 0.9109
# Epoch 3, Step 466/938, Total Step 3280, loss 0.01716, detection recall 0.0000, detection precision 0.0000, correction recall 0.6033, correction precision 0.9200
# Epoch 3, Step 486/938, Total Step 3300, loss 0.01973, detection recall 0.0000, detection precision 0.0000, correction recall 0.5775, correction precision 0.8920
# Epoch 3, Step 506/938, Total Step 3320, loss 0.01656, detection recall 0.0000, detection precision 0.0000, correction recall 0.5833, correction precision 0.9100
# Epoch 3, Step 526/938, Total Step 3340, loss 0.01954, detection recall 0.0000, detection precision 0.0000, correction recall 0.6017, correction precision 0.9000
# Epoch 3, Step 546/938, Total Step 3360, loss 0.02002, detection recall 0.0000, detection precision 0.0000, correction recall 0.5822, correction precision 0.8510
# Epoch 3, Step 566/938, Total Step 3380, loss 0.02037, detection recall 0.0000, detection precision 0.0000, correction recall 0.5276, correction precision 0.8821
# Epoch 3, Step 586/938, Total Step 3400, loss 0.01944, detection recall 0.0000, detection precision 0.0000, correction recall 0.5566, correction precision 0.8585
# Epoch 3, Step 606/938, Total Step 3420, loss 0.01806, detection recall 0.0000, detection precision 0.0000, correction recall 0.5981, correction precision 0.9000
# Epoch 3, Step 626/938, Total Step 3440, loss 0.01880, detection recall 0.0000, detection precision 0.0000, correction recall 0.5820, correction precision 0.9141
# Epoch 3, Step 646/938, Total Step 3460, loss 0.01869, detection recall 0.0000, detection precision 0.0000, correction recall 0.5796, correction precision 0.9146
# Epoch 3, Step 666/938, Total Step 3480, loss 0.01873, detection recall 0.0000, detection precision 0.0000, correction recall 0.5732, correction precision 0.8664
# Epoch 3, Step 686/938, Total Step 3500, loss 0.01827, detection recall 0.0000, detection precision 0.0000, correction recall 0.5976, correction precision 0.8860
# Epoch 3, Step 706/938, Total Step 3520, loss 0.02391, detection recall 0.0000, detection precision 0.0000, correction recall 0.5533, correction precision 0.8496
# Epoch 3, Step 726/938, Total Step 3540, loss 0.02120, detection recall 0.0000, detection precision 0.0000, correction recall 0.5274, correction precision 0.9010
# Epoch 3, Step 746/938, Total Step 3560, loss 0.02029, detection recall 0.0000, detection precision 0.0000, correction recall 0.5503, correction precision 0.8838
# Epoch 3, Step 766/938, Total Step 3580, loss 0.02021, detection recall 0.0000, detection precision 0.0000, correction recall 0.5636, correction precision 0.8815
# Epoch 3, Step 786/938, Total Step 3600, loss 0.01870, detection recall 0.0000, detection precision 0.0000, correction recall 0.5968, correction precision 0.8995
# Epoch 3, Step 806/938, Total Step 3620, loss 0.01901, detection recall 0.0000, detection precision 0.0000, correction recall 0.5756, correction precision 0.8950
# Epoch 3, Step 826/938, Total Step 3640, loss 0.02135, detection recall 0.0062, detection precision 1.0000, correction recall 0.5262, correction precision 0.8593
# Epoch 3, Step 846/938, Total Step 3660, loss 0.01768, detection recall 0.0000, detection precision 0.0000, correction recall 0.5908, correction precision 0.8889
# Epoch 3, Step 866/938, Total Step 3680, loss 0.01902, detection recall 0.0000, detection precision 0.0000, correction recall 0.5728, correction precision 0.9343
# Epoch 3, Step 886/938, Total Step 3700, loss 0.01536, detection recall 0.0000, detection precision 0.0000, correction recall 0.6364, correction precision 0.9043
# Epoch 3, Step 906/938, Total Step 3720, loss 0.01971, detection recall 0.0000, detection precision 0.0000, correction recall 0.5481, correction precision 0.8906
# Epoch 3, Step 926/938, Total Step 3740, loss 0.02093, detection recall 0.0000, detection precision 0.0000, correction recall 0.5583, correction precision 0.9010
# Epoch 4, Step 8/938, Total Step 3760, loss 0.01789, detection recall 0.0061, detection precision 0.6667, correction recall 0.6300, correction precision 0.9035
# Epoch 4, Step 28/938, Total Step 3780, loss 0.01408, detection recall 0.0032, detection precision 1.0000, correction recall 0.6484, correction precision 0.9178
# Epoch 4, Step 48/938, Total Step 3800, loss 0.01240, detection recall 0.0000, detection precision 0.0000, correction recall 0.7124, correction precision 0.9552
# Epoch 4, Step 68/938, Total Step 3820, loss 0.01356, detection recall 0.0034, detection precision 1.0000, correction recall 0.6812, correction precision 0.9398
# Epoch 4, Step 88/938, Total Step 3840, loss 0.01255, detection recall 0.0000, detection precision 0.0000, correction recall 0.7152, correction precision 0.9390
# Epoch 4, Step 108/938, Total Step 3860, loss 0.01285, detection recall 0.0032, detection precision 0.5000, correction recall 0.7097, correction precision 0.9091
# Epoch 4, Step 128/938, Total Step 3880, loss 0.01516, detection recall 0.0000, detection precision 0.0000, correction recall 0.6863, correction precision 0.9057
# Epoch 4, Step 148/938, Total Step 3900, loss 0.01287, detection recall 0.0062, detection precision 0.6667, correction recall 0.7138, correction precision 0.9431
# Epoch 4, Step 168/938, Total Step 3920, loss 0.01464, detection recall 0.0090, detection precision 1.0000, correction recall 0.6737, correction precision 0.9414
# Epoch 4, Step 188/938, Total Step 3940, loss 0.01463, detection recall 0.0058, detection precision 1.0000, correction recall 0.6919, correction precision 0.9261
# Epoch 4, Step 208/938, Total Step 3960, loss 0.01438, detection recall 0.0086, detection precision 1.0000, correction recall 0.6857, correction precision 0.9302
# Epoch 4, Step 228/938, Total Step 3980, loss 0.01292, detection recall 0.0063, detection precision 1.0000, correction recall 0.6984, correction precision 0.9322
# Epoch 4, Step 248/938, Total Step 4000, loss 0.01312, detection recall 0.0032, detection precision 1.0000, correction recall 0.7161, correction precision 0.9116
# Epoch 4, Step 268/938, Total Step 4020, loss 0.01236, detection recall 0.0000, detection precision 0.0000, correction recall 0.6859, correction precision 0.9386
# Epoch 4, Step 288/938, Total Step 4040, loss 0.01259, detection recall 0.0130, detection precision 1.0000, correction recall 0.7134, correction precision 0.9163
# Epoch 4, Step 308/938, Total Step 4060, loss 0.01431, detection recall 0.0031, detection precision 0.3333, correction recall 0.6635, correction precision 0.9378
# Epoch 4, Step 328/938, Total Step 4080, loss 0.01343, detection recall 0.0090, detection precision 1.0000, correction recall 0.7199, correction precision 0.9373
# Epoch 4, Step 348/938, Total Step 4100, loss 0.01319, detection recall 0.0247, detection precision 0.8889, correction recall 0.6944, correction precision 0.9454
# Epoch 4, Step 368/938, Total Step 4120, loss 0.01317, detection recall 0.0156, detection precision 0.8333, correction recall 0.7414, correction precision 0.9407
# Epoch 4, Step 388/938, Total Step 4140, loss 0.01424, detection recall 0.0120, detection precision 0.8000, correction recall 0.6988, correction precision 0.9393
# Epoch 4, Step 408/938, Total Step 4160, loss 0.01389, detection recall 0.0089, detection precision 1.0000, correction recall 0.7240, correction precision 0.9494
# Epoch 4, Step 428/938, Total Step 4180, loss 0.01252, detection recall 0.0095, detection precision 1.0000, correction recall 0.7161, correction precision 0.9342
# Epoch 4, Step 448/938, Total Step 4200, loss 0.01394, detection recall 0.0032, detection precision 0.5000, correction recall 0.6741, correction precision 0.8987
# Epoch 4, Step 468/938, Total Step 4220, loss 0.01477, detection recall 0.0127, detection precision 1.0000, correction recall 0.6540, correction precision 0.9115
# Epoch 4, Step 488/938, Total Step 4240, loss 0.01394, detection recall 0.0062, detection precision 1.0000, correction recall 0.6738, correction precision 0.9241
# Epoch 4, Step 508/938, Total Step 4260, loss 0.01357, detection recall 0.0131, detection precision 1.0000, correction recall 0.6797, correction precision 0.9083
# Epoch 4, Step 528/938, Total Step 4280, loss 0.01326, detection recall 0.0099, detection precision 0.7500, correction recall 0.7204, correction precision 0.9125
# Epoch 4, Step 548/938, Total Step 4300, loss 0.01263, detection recall 0.0095, detection precision 0.7500, correction recall 0.7161, correction precision 0.9190
# Epoch 4, Step 568/938, Total Step 4320, loss 0.01442, detection recall 0.0089, detection precision 0.6000, correction recall 0.6914, correction precision 0.9209
# Epoch 4, Step 588/938, Total Step 4340, loss 0.01419, detection recall 0.0123, detection precision 1.0000, correction recall 0.6871, correction precision 0.9256
# Epoch 4, Step 608/938, Total Step 4360, loss 0.01260, detection recall 0.0129, detection precision 1.0000, correction recall 0.7226, correction precision 0.9492
# Epoch 4, Step 628/938, Total Step 4380, loss 0.01576, detection recall 0.0163, detection precision 1.0000, correction recall 0.6938, correction precision 0.9209
# Epoch 4, Step 648/938, Total Step 4400, loss 0.01414, detection recall 0.0088, detection precision 1.0000, correction recall 0.6814, correction precision 0.9203
# Epoch 4, Step 668/938, Total Step 4420, loss 0.01448, detection recall 0.0122, detection precision 0.6667, correction recall 0.6636, correction precision 0.9156
# Epoch 4, Step 688/938, Total Step 4440, loss 0.01410, detection recall 0.0031, detection precision 1.0000, correction recall 0.6811, correction precision 0.9016
# Epoch 4, Step 708/938, Total Step 4460, loss 0.01562, detection recall 0.0117, detection precision 1.0000, correction recall 0.6997, correction precision 0.9195
# Epoch 4, Step 728/938, Total Step 4480, loss 0.01268, detection recall 0.0103, detection precision 0.7500, correction recall 0.6986, correction precision 0.9148
# Epoch 4, Step 748/938, Total Step 4500, loss 0.01359, detection recall 0.0059, detection precision 1.0000, correction recall 0.6953, correction precision 0.9553
# Epoch 4, Step 768/938, Total Step 4520, loss 0.01385, detection recall 0.0185, detection precision 1.0000, correction recall 0.6944, correction precision 0.9109
# Epoch 4, Step 788/938, Total Step 4540, loss 0.01380, detection recall 0.0029, detection precision 0.5000, correction recall 0.7257, correction precision 0.9077
# Epoch 4, Step 808/938, Total Step 4560, loss 0.01535, detection recall 0.0239, detection precision 0.8889, correction recall 0.6985, correction precision 0.9105
# Epoch 4, Step 828/938, Total Step 4580, loss 0.01261, detection recall 0.0159, detection precision 0.8333, correction recall 0.7175, correction precision 0.9417
# Epoch 4, Step 848/938, Total Step 4600, loss 0.01266, detection recall 0.0093, detection precision 1.0000, correction recall 0.7037, correction precision 0.9306
# Epoch 4, Step 868/938, Total Step 4620, loss 0.01452, detection recall 0.0206, detection precision 0.8750, correction recall 0.7227, correction precision 0.9041
# Epoch 4, Step 888/938, Total Step 4640, loss 0.01339, detection recall 0.0125, detection precision 1.0000, correction recall 0.6729, correction precision 0.9270
# Epoch 4, Step 908/938, Total Step 4660, loss 0.01139, detection recall 0.0162, detection precision 1.0000, correction recall 0.7468, correction precision 0.9388
# Epoch 4, Step 928/938, Total Step 4680, loss 0.01465, detection recall 0.0184, detection precision 1.0000, correction recall 0.6718, correction precision 0.8866
# Epoch 5, Step 10/938, Total Step 4700, loss 0.01232, detection recall 0.0233, detection precision 0.8750, correction recall 0.7243, correction precision 0.9277
# Epoch 5, Step 30/938, Total Step 4720, loss 0.00949, detection recall 0.0137, detection precision 1.0000, correction recall 0.7534, correction precision 0.9565
# Epoch 5, Step 50/938, Total Step 4740, loss 0.01025, detection recall 0.0200, detection precision 1.0000, correction recall 0.7971, correction precision 0.9588
# Epoch 5, Step 70/938, Total Step 4760, loss 0.00945, detection recall 0.0251, detection precision 0.8000, correction recall 0.7931, correction precision 0.9656
# Epoch 5, Step 90/938, Total Step 4780, loss 0.00947, detection recall 0.0265, detection precision 1.0000, correction recall 0.7781, correction precision 0.9553
# Epoch 5, Step 110/938, Total Step 4800, loss 0.01041, detection recall 0.0210, detection precision 0.8750, correction recall 0.8108, correction precision 0.9278
# Epoch 5, Step 130/938, Total Step 4820, loss 0.00911, detection recall 0.0124, detection precision 0.8000, correction recall 0.8199, correction precision 0.9565
# Epoch 5, Step 150/938, Total Step 4840, loss 0.01001, detection recall 0.0093, detection precision 0.7500, correction recall 0.8006, correction precision 0.9414
# Epoch 5, Step 170/938, Total Step 4860, loss 0.01017, detection recall 0.0121, detection precision 0.6667, correction recall 0.7970, correction precision 0.9564
# Epoch 5, Step 190/938, Total Step 4880, loss 0.01094, detection recall 0.0122, detection precision 0.6667, correction recall 0.7903, correction precision 0.9489
# Epoch 5, Step 210/938, Total Step 4900, loss 0.00869, detection recall 0.0120, detection precision 1.0000, correction recall 0.8765, correction precision 0.9668
# Epoch 5, Step 230/938, Total Step 4920, loss 0.00851, detection recall 0.0138, detection precision 0.8000, correction recall 0.8241, correction precision 0.9795
# Epoch 5, Step 250/938, Total Step 4940, loss 0.00990, detection recall 0.0153, detection precision 0.8333, correction recall 0.7829, correction precision 0.9517
# Epoch 5, Step 270/938, Total Step 4960, loss 0.00839, detection recall 0.0094, detection precision 0.4286, correction recall 0.8401, correction precision 0.9537
# Epoch 5, Step 290/938, Total Step 4980, loss 0.00944, detection recall 0.0205, detection precision 1.0000, correction recall 0.8211, correction precision 0.9655
# Epoch 5, Step 310/938, Total Step 5000, loss 0.00885, detection recall 0.0282, detection precision 1.0000, correction recall 0.8276, correction precision 0.9670
# Epoch 5, Step 330/938, Total Step 5020, loss 0.00858, detection recall 0.0377, detection precision 0.8571, correction recall 0.8396, correction precision 0.9570
# Epoch 5, Step 350/938, Total Step 5040, loss 0.01054, detection recall 0.0114, detection precision 1.0000, correction recall 0.8205, correction precision 0.9412
# Epoch 5, Step 370/938, Total Step 5060, loss 0.00942, detection recall 0.0061, detection precision 0.6667, correction recall 0.8129, correction precision 0.9397
# Epoch 5, Step 390/938, Total Step 5080, loss 0.01093, detection recall 0.0275, detection precision 0.7500, correction recall 0.7890, correction precision 0.9382
# Epoch 5, Step 410/938, Total Step 5100, loss 0.00866, detection recall 0.0224, detection precision 0.8750, correction recall 0.8365, correction precision 0.9491
# Epoch 5, Step 430/938, Total Step 5120, loss 0.01029, detection recall 0.0214, detection precision 1.0000, correction recall 0.7890, correction precision 0.9451
# Epoch 5, Step 450/938, Total Step 5140, loss 0.00855, detection recall 0.0225, detection precision 1.0000, correction recall 0.8167, correction precision 0.9732
# Epoch 5, Step 470/938, Total Step 5160, loss 0.00933, detection recall 0.0245, detection precision 1.0000, correction recall 0.8221, correction precision 0.9606
# Epoch 5, Step 490/938, Total Step 5180, loss 0.00893, detection recall 0.0131, detection precision 1.0000, correction recall 0.8170, correction precision 0.9579
# Epoch 5, Step 510/938, Total Step 5200, loss 0.01088, detection recall 0.0147, detection precision 0.8333, correction recall 0.8270, correction precision 0.9691
# Epoch 5, Step 530/938, Total Step 5220, loss 0.01041, detection recall 0.0147, detection precision 0.7143, correction recall 0.8053, correction precision 0.9479
# Epoch 5, Step 550/938, Total Step 5240, loss 0.00957, detection recall 0.0193, detection precision 1.0000, correction recall 0.8135, correction precision 0.9370
# Epoch 5, Step 570/938, Total Step 5260, loss 0.01071, detection recall 0.0132, detection precision 1.0000, correction recall 0.7862, correction precision 0.9484
# Epoch 5, Step 590/938, Total Step 5280, loss 0.00930, detection recall 0.0386, detection precision 1.0000, correction recall 0.8199, correction precision 0.9733
# Epoch 5, Step 610/938, Total Step 5300, loss 0.00966, detection recall 0.0162, detection precision 0.7143, correction recall 0.8058, correction precision 0.9396
# Epoch 5, Step 630/938, Total Step 5320, loss 0.00910, detection recall 0.0249, detection precision 0.8000, correction recall 0.8131, correction precision 0.9703
# Epoch 5, Step 650/938, Total Step 5340, loss 0.00860, detection recall 0.0288, detection precision 1.0000, correction recall 0.8462, correction precision 0.9531
# Epoch 5, Step 670/938, Total Step 5360, loss 0.00881, detection recall 0.0189, detection precision 1.0000, correction recall 0.8176, correction precision 0.9253
# Epoch 5, Step 690/938, Total Step 5380, loss 0.00945, detection recall 0.0162, detection precision 0.6250, correction recall 0.7929, correction precision 0.9351
# Epoch 5, Step 710/938, Total Step 5400, loss 0.00945, detection recall 0.0192, detection precision 1.0000, correction recall 0.8219, correction precision 0.9524
# Epoch 5, Step 730/938, Total Step 5420, loss 0.00912, detection recall 0.0094, detection precision 0.7500, correction recall 0.8464, correction precision 0.9541
# Epoch 5, Step 750/938, Total Step 5440, loss 0.01011, detection recall 0.0100, detection precision 0.7500, correction recall 0.7533, correction precision 0.9741
# Epoch 5, Step 770/938, Total Step 5460, loss 0.00983, detection recall 0.0113, detection precision 0.8000, correction recall 0.8385, correction precision 0.9579
# Epoch 5, Step 790/938, Total Step 5480, loss 0.01042, detection recall 0.0208, detection precision 0.7778, correction recall 0.8101, correction precision 0.9349
# Epoch 5, Step 810/938, Total Step 5500, loss 0.01150, detection recall 0.0116, detection precision 0.8000, correction recall 0.7855, correction precision 0.9410
# Epoch 5, Step 830/938, Total Step 5520, loss 0.00923, detection recall 0.0227, detection precision 0.7778, correction recall 0.8312, correction precision 0.9377
# Epoch 5, Step 850/938, Total Step 5540, loss 0.00838, detection recall 0.0218, detection precision 1.0000, correction recall 0.8660, correction precision 0.9488
# Epoch 5, Step 870/938, Total Step 5560, loss 0.00959, detection recall 0.0030, detection precision 0.5000, correction recall 0.8036, correction precision 0.9433
# Epoch 5, Step 890/938, Total Step 5580, loss 0.01193, detection recall 0.0150, detection precision 0.8333, correction recall 0.7688, correction precision 0.9446
# Epoch 5, Step 910/938, Total Step 5600, loss 0.00835, detection recall 0.0274, detection precision 0.8182, correction recall 0.8359, correction precision 0.9516
# Epoch 5, Step 930/938, Total Step 5620, loss 0.01011, detection recall 0.0188, detection precision 0.8571, correction recall 0.7900, correction precision 0.9403
# Epoch 6, Step 12/938, Total Step 5640, loss 0.00893, detection recall 0.0153, detection precision 0.8333, correction recall 0.8563, correction precision 0.9492
# Epoch 6, Step 32/938, Total Step 5660, loss 0.00731, detection recall 0.0312, detection precision 1.0000, correction recall 0.9093, correction precision 0.9727
# Epoch 6, Step 52/938, Total Step 5680, loss 0.00589, detection recall 0.0173, detection precision 1.0000, correction recall 0.9343, correction precision 0.9818
# Epoch 6, Step 72/938, Total Step 5700, loss 0.00707, detection recall 0.0158, detection precision 0.6250, correction recall 0.8896, correction precision 0.9758
# Epoch 6, Step 92/938, Total Step 5720, loss 0.00740, detection recall 0.0115, detection precision 1.0000, correction recall 0.9107, correction precision 0.9875
# Epoch 6, Step 112/938, Total Step 5740, loss 0.00773, detection recall 0.0328, detection precision 0.8462, correction recall 0.8746, correction precision 0.9899
# Epoch 6, Step 132/938, Total Step 5760, loss 0.00641, detection recall 0.0277, detection precision 0.9000, correction recall 0.9108, correction precision 0.9769
# Epoch 6, Step 152/938, Total Step 5780, loss 0.00601, detection recall 0.0221, detection precision 0.8750, correction recall 0.9211, correction precision 0.9766
# Epoch 6, Step 172/938, Total Step 5800, loss 0.00688, detection recall 0.0264, detection precision 0.7273, correction recall 0.9043, correction precision 0.9614
# Epoch 6, Step 192/938, Total Step 5820, loss 0.00703, detection recall 0.0185, detection precision 1.0000, correction recall 0.8892, correction precision 0.9731
# Epoch 6, Step 212/938, Total Step 5840, loss 0.00658, detection recall 0.0101, detection precision 0.7500, correction recall 0.8721, correction precision 0.9737
# Epoch 6, Step 232/938, Total Step 5860, loss 0.00712, detection recall 0.0093, detection precision 0.6000, correction recall 0.9037, correction precision 0.9732
# Epoch 6, Step 252/938, Total Step 5880, loss 0.00585, detection recall 0.0195, detection precision 0.7500, correction recall 0.9186, correction precision 0.9826
# Epoch 6, Step 272/938, Total Step 5900, loss 0.00698, detection recall 0.0121, detection precision 1.0000, correction recall 0.8912, correction precision 0.9547
# Epoch 6, Step 292/938, Total Step 5920, loss 0.00675, detection recall 0.0216, detection precision 0.7000, correction recall 0.9074, correction precision 0.9800
# Epoch 6, Step 312/938, Total Step 5940, loss 0.00682, detection recall 0.0344, detection precision 0.9167, correction recall 0.9000, correction precision 0.9796
# Epoch 6, Step 332/938, Total Step 5960, loss 0.00654, detection recall 0.0240, detection precision 0.8000, correction recall 0.9162, correction precision 0.9871
# ...
# Epoch 17, Step 874/938, Total Step 16820, loss 0.00179, detection recall 0.3598, detection precision 0.7815, correction recall 0.9970, correction precision 1.0000
# Epoch 17, Step 894/938, Total Step 16840, loss 0.00179, detection recall 0.3878, detection precision 0.7917, correction recall 0.9971, correction precision 0.9971
# Epoch 17, Step 914/938, Total Step 16860, loss 0.00162, detection recall 0.3673, detection precision 0.7484, correction recall 0.9969, correction precision 1.0000
# Epoch 17, Step 934/938, Total Step 16880, loss 0.00196, detection recall 0.3392, detection precision 0.6970, correction recall 0.9912, correction precision 0.9941
# Epoch 18, Step 16/938, Total Step 16900, loss 0.00153, detection recall 0.3937, detection precision 0.8370, correction recall 0.9930, correction precision 0.9965
# Epoch 18, Step 36/938, Total Step 16920, loss 0.00148, detection recall 0.4747, detection precision 0.8197, correction recall 0.9937, correction precision 1.0000
# Epoch 18, Step 56/938, Total Step 16940, loss 0.00169, detection recall 0.4796, detection precision 0.8407, correction recall 0.9969, correction precision 0.9937
# Epoch 18, Step 76/938, Total Step 16960, loss 0.00153, detection recall 0.5130, detection precision 0.8634, correction recall 0.9942, correction precision 1.0000
# Epoch 18, Step 96/938, Total Step 16980, loss 0.00174, detection recall 0.4444, detection precision 0.7955, correction recall 0.9968, correction precision 0.9905
# Epoch 18, Step 116/938, Total Step 17000, loss 0.00173, detection recall 0.3831, detection precision 0.7468, correction recall 0.9968, correction precision 0.9903
# Epoch 18, Step 136/938, Total Step 17020, loss 0.00171, detection recall 0.4469, detection precision 0.8035, correction recall 0.9839, correction precision 0.9967
# Epoch 18, Step 156/938, Total Step 17040, loss 0.00154, detection recall 0.4551, detection precision 0.7717, correction recall 0.9936, correction precision 1.0000
# Epoch 18, Step 176/938, Total Step 17060, loss 0.00177, detection recall 0.4701, detection precision 0.7772, correction recall 0.9910, correction precision 0.9940
# Epoch 18, Step 196/938, Total Step 17080, loss 0.00174, detection recall 0.4290, detection precision 0.7554, correction recall 0.9907, correction precision 1.0000
# Epoch 18, Step 216/938, Total Step 17100, loss 0.00176, detection recall 0.3982, detection precision 0.8086, correction recall 0.9939, correction precision 0.9939
# Epoch 18, Step 236/938, Total Step 17120, loss 0.00181, detection recall 0.4537, detection precision 0.8216, correction recall 0.9881, correction precision 0.9910
# Epoch 18, Step 256/938, Total Step 17140, loss 0.00177, detection recall 0.4311, detection precision 0.7869, correction recall 1.0000, correction precision 0.9940
# Epoch 18, Step 276/938, Total Step 17160, loss 0.00186, detection recall 0.4224, detection precision 0.7538, correction recall 0.9914, correction precision 0.9971
# Epoch 18, Step 296/938, Total Step 17180, loss 0.00166, detection recall 0.4130, detection precision 0.7910, correction recall 0.9971, correction precision 0.9971
# Epoch 18, Step 316/938, Total Step 17200, loss 0.00173, detection recall 0.4565, detection precision 0.8216, correction recall 0.9910, correction precision 1.0000
# Epoch 18, Step 336/938, Total Step 17220, loss 0.00181, detection recall 0.4140, detection precision 0.7784, correction recall 0.9936, correction precision 0.9936
# Epoch 18, Step 356/938, Total Step 17240, loss 0.00150, detection recall 0.4486, detection precision 0.8372, correction recall 0.9969, correction precision 0.9938
# Epoch 18, Step 376/938, Total Step 17260, loss 0.00143, detection recall 0.4430, detection precision 0.7821, correction recall 1.0000, correction precision 0.9968
# Epoch 18, Step 396/938, Total Step 17280, loss 0.00160, detection recall 0.4675, detection precision 0.7742, correction recall 0.9935, correction precision 0.9903
# Epoch 18, Step 416/938, Total Step 17300, loss 0.00153, detection recall 0.4589, detection precision 0.7880, correction recall 0.9937, correction precision 1.0000
# Epoch 18, Step 436/938, Total Step 17320, loss 0.00155, detection recall 0.4231, detection precision 0.7857, correction recall 0.9936, correction precision 0.9936
# Epoch 18, Step 456/938, Total Step 17340, loss 0.00179, detection recall 0.4406, detection precision 0.7958, correction recall 0.9913, correction precision 0.9942
# Epoch 18, Step 476/938, Total Step 17360, loss 0.00140, detection recall 0.4615, detection precision 0.7614, correction recall 1.0000, correction precision 1.0000
# Epoch 18, Step 496/938, Total Step 17380, loss 0.00149, detection recall 0.4448, detection precision 0.7829, correction recall 0.9968, correction precision 0.9968
# Epoch 18, Step 516/938, Total Step 17400, loss 0.00165, detection recall 0.4043, detection precision 0.7529, correction recall 0.9969, correction precision 1.0000
# Epoch 18, Step 536/938, Total Step 17420, loss 0.00187, detection recall 0.3861, detection precision 0.7597, correction recall 1.0000, correction precision 0.9934
# Epoch 18, Step 556/938, Total Step 17440, loss 0.00176, detection recall 0.4474, detection precision 0.7806, correction recall 0.9942, correction precision 1.0000
# Epoch 18, Step 576/938, Total Step 17460, loss 0.00170, detection recall 0.3746, detection precision 0.7564, correction recall 0.9937, correction precision 0.9937
# Epoch 18, Step 596/938, Total Step 17480, loss 0.00178, detection recall 0.4360, detection precision 0.8034, correction recall 0.9939, correction precision 0.9969
# Epoch 18, Step 616/938, Total Step 17500, loss 0.00155, detection recall 0.4263, detection precision 0.7727, correction recall 1.0000, correction precision 0.9969
# Epoch 18, Step 636/938, Total Step 17520, loss 0.00185, detection recall 0.4154, detection precision 0.8036, correction recall 0.9938, correction precision 0.9938
# Epoch 18, Step 656/938, Total Step 17540, loss 0.00187, detection recall 0.4189, detection precision 0.8161, correction recall 0.9971, correction precision 0.9971
# Epoch 18, Step 676/938, Total Step 17560, loss 0.00144, detection recall 0.4472, detection precision 0.7701, correction recall 0.9969, correction precision 0.9969
# Epoch 18, Step 696/938, Total Step 17580, loss 0.00187, detection recall 0.4180, detection precision 0.7849, correction recall 0.9845, correction precision 0.9937
# Epoch 18, Step 716/938, Total Step 17600, loss 0.00187, detection recall 0.4531, detection precision 0.7650, correction recall 0.9935, correction precision 0.9968
# Epoch 18, Step 736/938, Total Step 17620, loss 0.00180, detection recall 0.4103, detection precision 0.7072, correction recall 0.9872, correction precision 0.9968
# Epoch 18, Step 756/938, Total Step 17640, loss 0.00176, detection recall 0.3932, detection precision 0.7840, correction recall 0.9938, correction precision 0.9969
# Epoch 18, Step 776/938, Total Step 17660, loss 0.00153, detection recall 0.4375, detection precision 0.7527, correction recall 1.0000, correction precision 0.9969
# Epoch 18, Step 796/938, Total Step 17680, loss 0.00146, detection recall 0.4608, detection precision 0.7656, correction recall 0.9969, correction precision 0.9969
# Epoch 18, Step 816/938, Total Step 17700, loss 0.00170, detection recall 0.4150, detection precision 0.7697, correction recall 0.9935, correction precision 0.9967
# Epoch 18, Step 836/938, Total Step 17720, loss 0.00166, detection recall 0.4222, detection precision 0.7688, correction recall 1.0000, correction precision 0.9968
# Epoch 18, Step 856/938, Total Step 17740, loss 0.00154, detection recall 0.4755, detection precision 0.8168, correction recall 0.9942, correction precision 1.0000
# Epoch 18, Step 876/938, Total Step 17760, loss 0.00202, detection recall 0.4551, detection precision 0.7677, correction recall 0.9850, correction precision 1.0000
# Epoch 18, Step 896/938, Total Step 17780, loss 0.00163, detection recall 0.4149, detection precision 0.8121, correction recall 1.0000, correction precision 0.9938
# Epoch 18, Step 916/938, Total Step 17800, loss 0.00195, detection recall 0.4225, detection precision 0.7394, correction recall 0.9818, correction precision 0.9969
# Epoch 18, Step 936/938, Total Step 17820, loss 0.00164, detection recall 0.4713, detection precision 0.8168, correction recall 0.9909, correction precision 0.9939
# Epoch 19, Step 18/938, Total Step 17840, loss 0.00141, detection recall 0.4923, detection precision 0.8196, correction recall 0.9969, correction precision 1.0000
# Epoch 19, Step 38/938, Total Step 17860, loss 0.00131, detection recall 0.4506, detection precision 0.8111, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 58/938, Total Step 17880, loss 0.00114, detection recall 0.5206, detection precision 0.8410, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 78/938, Total Step 17900, loss 0.00128, detection recall 0.4905, detection precision 0.7868, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 98/938, Total Step 17920, loss 0.00110, detection recall 0.5743, detection precision 0.8286, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 118/938, Total Step 17940, loss 0.00126, detection recall 0.5033, detection precision 0.8462, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 138/938, Total Step 17960, loss 0.00173, detection recall 0.4726, detection precision 0.7885, correction recall 1.0000, correction precision 0.9943
# Epoch 19, Step 158/938, Total Step 17980, loss 0.00124, detection recall 0.5466, detection precision 0.8381, correction recall 0.9969, correction precision 1.0000
# Epoch 19, Step 178/938, Total Step 18000, loss 0.00137, detection recall 0.5148, detection precision 0.7850, correction recall 0.9934, correction precision 1.0000
# Epoch 19, Step 198/938, Total Step 18020, loss 0.00126, detection recall 0.4935, detection precision 0.7824, correction recall 1.0000, correction precision 0.9967
# Epoch 19, Step 218/938, Total Step 18040, loss 0.00114, detection recall 0.5368, detection precision 0.8373, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 238/938, Total Step 18060, loss 0.00134, detection recall 0.5184, detection precision 0.8048, correction recall 0.9969, correction precision 1.0000
# Epoch 19, Step 258/938, Total Step 18080, loss 0.00145, detection recall 0.5413, detection precision 0.8429, correction recall 0.9969, correction precision 1.0000
# Epoch 19, Step 278/938, Total Step 18100, loss 0.00167, detection recall 0.5079, detection precision 0.7960, correction recall 0.9937, correction precision 0.9874
# Epoch 19, Step 298/938, Total Step 18120, loss 0.00159, detection recall 0.5223, detection precision 0.8502, correction recall 0.9881, correction precision 0.9970
# Epoch 19, Step 318/938, Total Step 18140, loss 0.00121, detection recall 0.5353, detection precision 0.8520, correction recall 0.9968, correction precision 1.0000
# Epoch 19, Step 338/938, Total Step 18160, loss 0.00167, detection recall 0.5133, detection precision 0.7838, correction recall 0.9941, correction precision 0.9941
# Epoch 19, Step 358/938, Total Step 18180, loss 0.00140, detection recall 0.5174, detection precision 0.8279, correction recall 0.9971, correction precision 1.0000
# Epoch 19, Step 378/938, Total Step 18200, loss 0.00163, detection recall 0.4828, detection precision 0.8191, correction recall 0.9969, correction precision 0.9937
# Epoch 19, Step 398/938, Total Step 18220, loss 0.00129, detection recall 0.4715, detection precision 0.8441, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 418/938, Total Step 18240, loss 0.00136, detection recall 0.5401, detection precision 0.7919, correction recall 0.9938, correction precision 0.9969
# Epoch 19, Step 438/938, Total Step 18260, loss 0.00147, detection recall 0.4955, detection precision 0.7773, correction recall 0.9940, correction precision 0.9940
# Epoch 19, Step 458/938, Total Step 18280, loss 0.00146, detection recall 0.5329, detection precision 0.7807, correction recall 0.9940, correction precision 0.9970
# Epoch 19, Step 478/938, Total Step 18300, loss 0.00178, detection recall 0.4924, detection precision 0.8050, correction recall 0.9908, correction precision 0.9939
# Epoch 19, Step 498/938, Total Step 18320, loss 0.00134, detection recall 0.4984, detection precision 0.7969, correction recall 0.9902, correction precision 1.0000
# Epoch 19, Step 518/938, Total Step 18340, loss 0.00134, detection recall 0.5449, detection precision 0.7982, correction recall 1.0000, correction precision 0.9970
# Epoch 19, Step 538/938, Total Step 18360, loss 0.00132, detection recall 0.5357, detection precision 0.8219, correction recall 0.9940, correction precision 1.0000
# Epoch 19, Step 558/938, Total Step 18380, loss 0.00153, detection recall 0.5084, detection precision 0.8261, correction recall 0.9967, correction precision 0.9967
# Epoch 19, Step 578/938, Total Step 18400, loss 0.00138, detection recall 0.5123, detection precision 0.8058, correction recall 0.9969, correction precision 1.0000
# Epoch 19, Step 598/938, Total Step 18420, loss 0.00131, detection recall 0.5229, detection precision 0.7991, correction recall 1.0000, correction precision 1.0000
# Epoch 19, Step 618/938, Total Step 18440, loss 0.00110, detection recall 0.5900, detection precision 0.8510, correction recall 0.9967, correction precision 1.0000
# Epoch 19, Step 638/938, Total Step 18460, loss 0.00134, detection recall 0.5365, detection precision 0.8204, correction recall 0.9905, correction precision 0.9936
# Epoch 19, Step 658/938, Total Step 18480, loss 0.00145, detection recall 0.5205, detection precision 0.8049, correction recall 0.9937, correction precision 0.9968
# Epoch 19, Step 678/938, Total Step 18500, loss 0.00129, detection recall 0.5296, detection precision 0.8213, correction recall 1.0000, correction precision 0.9969
# Epoch 19, Step 698/938, Total Step 18520, loss 0.00159, detection recall 0.5397, detection precision 0.7981, correction recall 0.9905, correction precision 1.0000
# Epoch 19, Step 718/938, Total Step 18540, loss 0.00121, detection recall 0.5414, detection precision 0.8333, correction recall 1.0000, correction precision 0.9937
# Epoch 19, Step 738/938, Total Step 18560, loss 0.00147, detection recall 0.5133, detection precision 0.7768, correction recall 0.9912, correction precision 1.0000
# Epoch 19, Step 758/938, Total Step 18580, loss 0.00166, detection recall 0.4589, detection precision 0.7880, correction recall 0.9937, correction precision 0.9905
# Epoch 19, Step 778/938, Total Step 18600, loss 0.00132, detection recall 0.5331, detection precision 0.7478, correction recall 0.9968, correction precision 1.0000
# Epoch 19, Step 798/938, Total Step 18620, loss 0.00155, detection recall 0.5060, detection precision 0.7907, correction recall 0.9970, correction precision 0.9970
# Epoch 19, Step 818/938, Total Step 18640, loss 0.00155, detection recall 0.5215, detection precision 0.7834, correction recall 0.9969, correction precision 0.9939
# Epoch 19, Step 838/938, Total Step 18660, loss 0.00160, detection recall 0.5329, detection precision 0.8091, correction recall 0.9940, correction precision 0.9940
# Epoch 19, Step 858/938, Total Step 18680, loss 0.00166, detection recall 0.4371, detection precision 0.7604, correction recall 0.9970, correction precision 0.9970
# Epoch 19, Step 878/938, Total Step 18700, loss 0.00165, detection recall 0.5208, detection precision 0.8028, correction recall 0.9940, correction precision 0.9970
# Epoch 19, Step 898/938, Total Step 18720, loss 0.00145, detection recall 0.5184, detection precision 0.8204, correction recall 0.9939, correction precision 1.0000
# Epoch 19, Step 918/938, Total Step 18740, loss 0.00166, detection recall 0.5187, detection precision 0.8019, correction recall 0.9937, correction precision 0.9969
# Epoch 19, Step 938/938, Total Step 18760, loss 0.00135, detection recall 0.5016, detection precision 0.8135, correction recall 1.0000, correction precision 1.0000

# %% [markdown]
# # 模型评估

# %% [markdown]
# 模型评估使用了SIGHAN 2013,2014,2015三个数据集对模型进行评估。对于Detection的Precision和Recall的评估，使用的是Correction Network的结果，这和训练阶段有所不同，这是因为Detection Network只是帮助Correction Network训练的，其结果在使用时不具备参考价值。

# %%
eps = 1e-8

def input_check_and_process(src_sentences, tgt_sentences, pred_sentences):
    """
    check the input is valid
    @param src_sentences:
    @param tgt_sentences:
    @param pred_sentences:
    @return:
    """
    assert len(src_sentences) == len(tgt_sentences) == len(pred_sentences)
    src_char_list = [list(s) for s in src_sentences]
    tgt_char_list = [list(s) for s in tgt_sentences]
    pred_char_list = [list(s) for s in pred_sentences]
    assert all(
        [len(src) == len(tgt) == len(pred) for src, tgt, pred in zip(src_char_list, tgt_char_list, pred_char_list)]
    )
    return src_char_list, tgt_char_list, pred_char_list


def compute_p_r_f1(true_predict, all_predict, all_error):
    """
    @param true_predict:
    @param all_predict:
    @param all_error:
    @return:
    """
    p = round(true_predict / (all_predict + eps) * 100, 3)
    r = round(true_predict / (all_error + eps) * 100, 3)
    f1 = round(2 * p * r / (p + r + eps), 3)
    return {'p': p, 'r': r, 'f1': f1}



def calculate_metric(src_sentences, tgt_sentences, pred_sentences):
    """
    :param only_chinese: 是否只判断中文字符
    :param src_sentences: list of origin sentences
    :param tgt_sentences: list of target sentences
    :param pred_sentences: list of predict sentences
    :param report_file: report file path
    :param ignore_chars: chars that is not evaluated
    :return:
    """
    src_char_list, tgt_char_list, pred_char_list = input_check_and_process(src_sentences, tgt_sentences, pred_sentences)
    sentence_detection, sentence_correction, char_detection, char_correction = [
        {'all_error': 0, 'true_predict': 0, 'all_predict': 0} for _ in range(4)]
    output_errors = []
    for src_chars, tgt_chars, pred_chars in zip(src_char_list, tgt_char_list, pred_char_list):
        true_error_indexes = []
        detect_indexes = []
        for index, (src_char, tgt_char, pred_char) in enumerate(zip(src_chars, tgt_chars, pred_chars)):
            if src_char != tgt_char:
                char_detection['all_error'] += 1
                char_correction['all_error'] += 1
                true_error_indexes.append(index)
            if src_char != pred_char:
                char_detection['all_predict'] += 1
                char_correction['all_predict'] += 1
                detect_indexes.append(index)
                if src_char != tgt_char:
                    char_detection['true_predict'] += 1
                if pred_char == tgt_char:
                    char_correction['true_predict'] += 1
        if true_error_indexes:
            sentence_detection['all_error'] += 1
            sentence_correction['all_error'] += 1
        if detect_indexes:
            sentence_detection['all_predict'] += 1
            sentence_correction['all_predict'] += 1
            if tuple(true_error_indexes) == tuple(detect_indexes):
                sentence_detection['true_predict'] += 1
            if tuple(tgt_chars) == tuple(pred_chars):
                sentence_correction['true_predict'] += 1
        if tuple(tgt_chars) != tuple(pred_chars):
            origin_s = "".join(src_chars)
            target_s = "".join(tgt_chars)
            predict_s = "".join(pred_chars)
            if origin_s == target_s and origin_s != predict_s:
                error_type = "过纠"
            elif origin_s != target_s and origin_s == predict_s:
                error_type = "漏纠"
            else:
                error_type = '综合'
            output_errors.append(
                [
                    "原始: " + "".join(src_chars),
                    "正确: " + "".join([c2 if c1 == c2 else f"【{c2}】" for c1, c2 in zip(pred_chars, tgt_chars)]),
                    "预测: " + "".join([c1 if c1 == c2 else f"【{c1}】" for c1, c2 in zip(pred_chars, tgt_chars)]),
                    "错误类型: " + error_type
                ]
            )

    result = dict()
    for prefix_name, sub_metric in zip(['S_D_', 'S_C_', 'C_D_', 'C_C_'],
                                       [sentence_detection, sentence_correction, char_detection, char_correction]):
        sub_r = compute_p_r_f1(sub_metric['true_predict'], sub_metric['all_predict'], sub_metric['all_error']).items()
        for k, v in sub_r:
            result[prefix_name + k] = v
    return {'result': result}

# %%
model = model.eval()

# %%
def evaluation(test_data):
    d_recall_numerator = 0  # Detection的Recall的分子
    d_recall_denominator = 0  # Detection的Recall的分母
    d_precision_numerator = 0  # Detection的precision的分子
    d_precision_denominator = 0  # Detection的precision的分母
    c_recall_numerator = 0  # Correction的Recall的分子
    c_recall_denominator = 0  # Correction的Recall的分母
    c_precision_numerator = 0  # Correction的precision的分子
    c_precision_denominator = 0  # Correction的precision的分母
    
    predictions = []
    prograss = tqdm(range(len(test_data)))
    for i in prograss:
        src, tgt = test_data[i][0], test_data[i][1]

        src_tokens = tokenizer(src, return_tensors='pt', max_length=128, truncation=True)['input_ids'][0][1:-1]
        tgt_tokens = tokenizer(tgt, return_tensors='pt', max_length=128, truncation=True)['input_ids'][0][1:-1]

        # 正常情况下，src和tgt的长度应该是一致的
        if len(src_tokens) != len(tgt_tokens):
            print("第%d条数据异常" % i)
            continue

        correction_outputs, _ = model(src)
        
        predict_tokens = correction_outputs[0][1:len(src_tokens) + 1].argmax(1).detach().cpu()
        pred = tokenizer.decode(predict_tokens).replace(' ', '')
        predictions.append(pred)
    
    sources, targets = zip(*test_data)
    predictions = [p[: len(t)] if len(p) > len(t) else p + ' ' * (len(t) - len(p))
                           for (p, t) in zip(predictions, targets)]
    result = calculate_metric(sources, targets, predictions)
    print(result)
#         print(predict_tokens)
#         print(tokenizer.decode(predict_tokens))
        
#         # 计算错误token的数量
#         d_recall_denominator += (src_tokens != tgt_tokens).sum().item()
#         # 计算在这些错误token，有多少网络也认为它是错误的
#         d_recall_numerator += (predict_tokens != src_tokens)[src_tokens != tgt_tokens].sum().item()
#         # 计算网络找出的错误token的数量
#         d_precision_denominator += (predict_tokens != src_tokens).sum().item()
#         # 计算在网络找出的这些错误token中，有多少是真正错误的
#         d_precision_numerator += (src_tokens != tgt_tokens)[predict_tokens != src_tokens].sum().item()
#         # 计算Detection的recall、precision和f1-score
#         d_recall = d_recall_numerator / (d_recall_denominator + 1e-9)
#         d_precision = d_precision_numerator / (d_precision_denominator + 1e-9)
#         d_f1_score = 2 * (d_recall * d_precision) / (d_recall + d_precision + 1e-9)

#         # 计算错误token的数量
#         c_recall_denominator += (src_tokens != tgt_tokens).sum().item()
#         # 计算在这些错误token中，有多少网络预测对了
#         c_recall_numerator += (predict_tokens == tgt_tokens)[src_tokens != tgt_tokens].sum().item()
#         # 计算网络找出的错误token的数量
#         c_precision_denominator += (predict_tokens != src_tokens).sum().item()
#         # 计算网络找出的错误token中，有多少是正确修正的
#         c_precision_numerator += (predict_tokens == tgt_tokens)[predict_tokens != src_tokens].sum().item()

#         # 计算Correction的recall、precision和f1-score
#         c_recall = c_recall_numerator / (c_recall_denominator + 1e-9)
#         c_precision = c_precision_numerator / (c_precision_denominator + 1e-9)
#         c_f1_score = 2 * (c_recall * c_precision) / (c_recall + c_precision + 1e-9)

#         prograss.set_postfix({
#             'd_recall': d_recall,
#             'd_precision': d_precision,
#             'd_f1_score': d_f1_score,
#             'c_recall': c_recall,
#             'c_precision': c_precision,
#             'c_f1_score': c_f1_score,
#         })

# %%
eval_data = CSCDataset("/kaggle/input/cscd-ime/dev.tsv")
evaluation(eval_data)
# Out:
# 100%|██████████| 5000/5000 [01:12<00:00, 68.57it/s]
# {'result': {'S_D_p': 28.842, 'S_D_r': 32.195, 'S_D_f1': 30.426, 'S_C_p': 28.262, 'S_C_r': 31.547, 'S_C_f1': 29.814, 'C_D_p': 3.004, 'C_D_r': 54.933, 'C_D_f1': 5.696, 'C_C_p': 2.306, 'C_C_r': 42.169, 'C_C_f1': 4.373}}

# %%
test_data = CSCDataset("/kaggle/input/cscd-ime/test.tsv")
evaluation(test_data)
# Out:
# 100%|██████████| 5000/5000 [01:11<00:00, 69.89it/s]
# {'result': {'S_D_p': 31.093, 'S_D_r': 35.562, 'S_D_f1': 33.178, 'S_C_p': 30.372, 'S_C_r': 34.737, 'S_C_f1': 32.408, 'C_D_p': 3.165, 'C_D_r': 58.109, 'C_D_f1': 6.003, 'C_C_p': 2.467, 'C_C_r': 45.293, 'C_C_f1': 4.679}}

# %% [markdown]
# # 模型使用

# %% [markdown]
# 最后，我们来真正的使用一下该模型，看下效果：

# %%
# def predict(text):
#     sequences = [text]
#     correction_outputs, _ = model(sequences)
#     tokens = correction_outputs[0][1:len(text) + 1].argmax(1)
#     return ''.join(tokenizer.convert_ids_to_tokens(tokens))

# %%
# predict("今天早上我吃了以个火聋果")

# %%
# predict("我是联系时长两年半的个人练习生蔡徐鲲，喜欢唱跳RAP蓝球")

# %% [markdown]
# 虽然在数据上模型表现还不错，但在真正使用场景上，效果还是不够好。中文文本纠错果然是一个比较难的任务 T_T !

# %% [markdown]
# # 参考文献
#
# [MDCSpell论文](https://aclanthology.org/2022.findings-acl.98/): https://aclanthology.org/2022.findings-acl.98/
#
# [MDCSpell论文笔记](https://blog.csdn.net/zhaohongfei_358/article/details/126973451)：https://blog.csdn.net/zhaohongfei_358/article/details/126973451
